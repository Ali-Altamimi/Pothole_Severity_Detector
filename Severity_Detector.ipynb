# %%
# from yolov5 import train, val, detect, export
import torch

# %%
# Model
model = torch.hub.load('ultralytics/yolov5', 'custom', './model/best.pt')  # or yolov5m, yolov5l, yolov5x, etc.
# model = torch.hub.load('ultralytics/yolov5', 'custom', 'path/to/best.pt')  # custom trained model

# Images
im = './data/datasets/images/test/0271.png'  # or file, Path, URL, PIL, OpenCV, numpy, list

# Inference
results = model(im)

# Results
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.

results.xyxy[0]  # im predictions (tensor)
results.pandas().xyxy[0]  # im predictions (pandas)
# Out:
# Using cache found in C:\Users\Ali Altamimi/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-1-21 Python-3.9.15 torch-1.13.1+cpu CPU
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20861016 parameters, 0 gradients, 47.9 GFLOPs
# Adding AutoShape...
# image 1/1: 1080x1920 1 low, 1 high
# Speed: 42.1ms pre-process, 156.2ms inference, 1.5ms NMS per image at shape (1, 3, 384, 640)
#         xmin        ymin        xmax        ymax  confidence  class  name
# 0   0.000000  758.081238  218.126953  960.038147    0.774959      2  high
# 1  53.986862  451.684113  764.981323  622.607117    0.548593      0   low

# %%
x = results.pandas().xyxy[0]
max_value = results.pandas().xyxy[0]['class'].max()

# %%
x[x['class'] == max_value]['name'].values[0]
# Out:
# 'high'

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>
